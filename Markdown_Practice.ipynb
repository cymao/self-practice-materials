# %% [markdown]
# 1. markdown and code interchange

# %% [markdown]
# 2. Headings
#
# # titles

# %% [markdown]
# 2 Headings
# #titles

# %% [markdown]
# 2. headings
#
# # titles
# ## titles
# ### titles
# #### titles

# %% [markdown]
# 3. emphasis texts
#
# ** bold **

# %% [markdown]
# 3. emphasis texts
#
# **bold**
#
# *bold*

# %% [markdown]
# 4. equation
#
# exponential exquation: $e^(x-1)-x$

# %% [markdown]
# 4. equation
#
# exponential exquation: $e^(x - 1) - x$

# %% [markdown]
# 4. equation
#
# exponential exquation: $e^ (x - 1) - x$

# %% [markdown]
# 4. equation
#
# exponential exquation: $e^{x-1}-x$

# %% [markdown]
# 5. mnonspace font
#
# `string`

# %% [markdown]
# 6. line break <br> line break

# %% [markdown]
# 7. indenting
#
# > text that will be intendted when the markdown is rendered. but when it will stop > ?
#
# text that will be intendted when the markdown is rendered.

# %% [markdown]
# 8. bullet
#
# * bullet
#
# - bullet
#
#  - bullet
#
#     whats going on?

# %% [markdown]
# **bullet**
#
# * bullet
#
# - bullet
#
#  - bullet
#
#     whats going on?

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Tip:</b> Use blue boxes (alert-info) for tips and notes.
# If it’s a note, you don’t have to include the word “Note”.
# </div>

# %% [markdown]
# geographic shape
#
# &# 9636

# %% [markdown]
# add graph, but only works if the attachement in the local desktop. Otherwise, pics have to added to repository as well!
#
# ![text%20graph.JPG](attachment:text%20graph.JPG)

# %% [markdown]
# horitontal lines
# ***
# what does that mean?
# ______
# test

# %% [markdown]
# add external link:
# [Markdown cheatsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Here-Cheatsheet#hr)

# %% [markdown]
# [I'm an inline-style link](https://www.google.com)
